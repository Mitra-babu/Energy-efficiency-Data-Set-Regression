# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# #  Data Read

# %%
# !pwd
# !ls
# Out:
# /home/mitra/new/IIITG/Machine_Learning/LinearRegression/Energy efficiency Data Set
#  ENB2012_data.xlsx  'Energy efficiency Data Set Regression.ipynb'

# %%
df=pd.read_excel('/home/mitra/new/IIITG/Machine_Learning/LinearRegression/Energy efficiency Data Set/ENB2012_data.xlsx')
df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2  Unnamed: 10  \
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33          NaN
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33          NaN
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33          NaN
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33          NaN
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28          NaN
#
#    Unnamed: 11
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# # EDA

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df=df.drop(['Unnamed: 10','Unnamed: 11'],axis=1)

# %%
df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
X=df.iloc[:,:-2]
X.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0

# %%
Y=df.iloc[:,8:]
Y.head()
# Out:
#       Y1     Y2
# 0  15.55  21.33
# 1  15.55  21.33
# 2  15.55  21.33
# 3  15.55  21.33
# 4  20.84  28.28

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
LR=LinearRegression()

# %%
LR.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=LR.predict(X_test)

# %%
score=r2_score(Y_test,y_pred)

# %%
score
# Out:
# 0.8973911074905536
